# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("../Dataset/bike_buyers_clean.csv")

# %%
df.head()
# Out:
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
encode = OneHotEncoder(sparse_output=False)
# encode.set_output(transform="pandas")

# %%
encode.fit_transform(df[["Gender", "Marital Status", "Home Owner"]])
encode.set_output(transform="pandas")
# Out:
# OneHotEncoder(sparse_output=False)

# %%
m =encode.get_feature_names_out()

# %%
e = encode.feature_names_in_

# %%
df = pd.read_csv("../Dataset/bike_buyers_clean.csv")

# %%
df2 = encode.fit_transform(df[["Gender", "Region"]])

# %%
df1 = df.drop(columns=e)
df1
# Out:
#         ID Marital Status  Income  Children        Education      Occupation  \
# 0    12496        Married   40000         1        Bachelors  Skilled Manual
# 1    24107        Married   30000         3  Partial College        Clerical
# 2    14177        Married   80000         5  Partial College    Professional
# 3    24381         Single   70000         0        Bachelors    Professional
# 4    25597         Single   30000         0        Bachelors        Clerical
# ..     ...            ...     ...       ...              ...             ...
# 995  23731        Married   60000         2      High School    Professional
# 996  28672         Single   70000         4  Graduate Degree    Professional
# 997  11809        Married   60000         2        Bachelors  Skilled Manual
# 998  19664         Single  100000         3        Bachelors      Management
# 999  12121         Single   60000         3      High School    Professional
#
# ...

# %%
pd.concat([df1, df2], axis=1)
# Out:
#         ID Marital Status  Income  Children        Education      Occupation  \
# 0    12496        Married   40000         1        Bachelors  Skilled Manual
# 1    24107        Married   30000         3  Partial College        Clerical
# 2    14177        Married   80000         5  Partial College    Professional
# 3    24381         Single   70000         0        Bachelors    Professional
# 4    25597         Single   30000         0        Bachelors        Clerical
# ..     ...            ...     ...       ...              ...             ...
# 995  23731        Married   60000         2      High School    Professional
# 996  28672         Single   70000         4  Graduate Degree    Professional
# 997  11809        Married   60000         2        Bachelors  Skilled Manual
# 998  19664         Single  100000         3        Bachelors      Management
# 999  12121         Single   60000         3      High School    Professional
#
# ...
