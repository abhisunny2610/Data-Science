# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Bar Graph

# %%
fruits = ["Banana", "Graphs", "Orange", "Papaya"]
counts = [4,10,7,5]

plt.bar(x=fruits, height=counts)
plt.show()

# %% [markdown]
# ## Bar color

# %%
fruits = ["Banana", "Graphs", "Orange", "cherry"]
counts = [4,10,7,5]
bar_colors = ["yellow", "green", "orange", "red"]

plt.bar(x=fruits, height=counts, color=bar_colors)
plt.show()

# %% [markdown]
# ## Chart labels and legends and Title

# %%
fruits = ["Banana", "Graphs", "Orange", "Papaya"]
counts = [4,10,7,5]
bar_colors = ["yellow", "green", "orange", "red"]
bar_labels = ["Banana", "Graphs", "Orange", "Cherry"]

## create a figure
fig, axes = plt.subplots()

## create bars
p = axes.bar(x=fruits, height=counts, color=bar_colors, label = bar_labels)

## set x label
axes.set_xlabel("Fruits")

## set y label
axes.set_ylabel("Counts")

## set legends
axes.legend()

## set bar labels
axes.bar_label(p, label_type='center')

## set fig title
plt.title("Fruits and their counts")

## show figure
plt.show()

# %% [markdown]
# ## Grouped bar, stacked bar and horizontal bar

# %%
religion = ["Hinduism", 'Islam', "Sikhism", 'Christianity']
sex_counts = {
    'Male': np.array([60, 40, 50, 70]),
    'Female': np.array([40,60,50,30])
}

# df_religion = pd.DataFrame(data=sex_counts, index=religion)

fig, ax = plt.subplots(figsize=(6,4), tight_layout=True)
width = 0.6

bottom = np.zeros(4)

for sex, sex_count in sex_counts.items():
    p = ax.bar(religion, sex_count, width=width, bottom=bottom, label=sex)
    bottom += sex_count
    ax.bar_label(p, label_type="center")

ax.set_title("Number of Religion by sex")
ax.legend(loc="upper right", ncol=2)
plt.show()

# %%
## horizontal bar chart

people = ["Hanish", "Manish", "Abhi", "Saurabh", "Sumit"]
performance = np.random.randint(8, 15, 5)
set_label = np.arange(len(people))
fig, axes = plt.subplots()

hbars = axes.barh(set_label, performance,xerr=1, align='center', color='r')
axes.bar_label(hbars)
axes.set_yticks(set_label, labels=people)
axes.set_xlabel("Performance")
axes.set_ylabel("Name")
ax.set_xlim(right=15)

plt.show()

# %% [markdown]
# ## Group bar chart with labels

# %%
species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

labels = np.arange(len(species))

fig, ax = plt.subplots()

width=0.3
offset = 0

for col, values in penguin_means.items():
    rgb = (random.random(), random.random(), random.random())
    bars = ax.bar(labels+offset, values, width=width, label=col, color=[rgb])
    offset +=width
    ax.bar_label(bars, padding=3)

ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(labels + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0,250)
plt.show()

# %% [markdown]
# ## Pie chart
#
# A pie chart is a type of graph representing data in a circular form, with each slice of the circle representing a fraction or proportionate part of the whole. All slices of the pie add up to make the whole equaling 100 percent and 360 degrees.

# %%
labels = ["Student", "Teachers", "Employee"]
sizes = [1440, 200, 150]

fix, ax = plt.subplots()
rgb=(random.random(), random.random(), random.random())
ax.pie(sizes, labels=labels)
plt.show()

# %% [markdown]
# ### Auto-label slices

# %%
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, hatch=['**O', 'oO'])
plt.show()

# %% [markdown]
# ## Explode, shade, and rotate slices

# %%
explode = (0,0.2, 0)

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%', startangle=20, shadow=True)
plt.show()

# %% [markdown]
# ## Histogram Chart

# %%
students_marks = np.random.randint(30,100,50)

plt.hist(students_marks)
plt.vlines(students_marks.mean(),ymax=10, ymin=0, color='yellow')
plt.show()
