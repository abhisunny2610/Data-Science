# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Matplotlib
#
# Matplotlib is a comprehensive library for creating static, animated and interactive data visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
x = np.linspace(1,10, 200)

# %%
x
# Out:
# array([ 1.        ,  1.04522613,  1.09045226,  1.13567839,  1.18090452,
#         1.22613065,  1.27135678,  1.31658291,  1.36180905,  1.40703518,
#         1.45226131,  1.49748744,  1.54271357,  1.5879397 ,  1.63316583,
#         1.67839196,  1.72361809,  1.76884422,  1.81407035,  1.85929648,
#         1.90452261,  1.94974874,  1.99497487,  2.04020101,  2.08542714,
#         2.13065327,  2.1758794 ,  2.22110553,  2.26633166,  2.31155779,
#         2.35678392,  2.40201005,  2.44723618,  2.49246231,  2.53768844,
#         2.58291457,  2.6281407 ,  2.67336683,  2.71859296,  2.7638191 ,
#         2.80904523,  2.85427136,  2.89949749,  2.94472362,  2.98994975,
#         3.03517588,  3.08040201,  3.12562814,  3.17085427,  3.2160804 ,
#         3.26130653,  3.30653266,  3.35175879,  3.39698492,  3.44221106,
#         3.48743719,  3.53266332,  3.57788945,  3.62311558,  3.66834171,
#         3.71356784,  3.75879397,  3.8040201 ,  3.84924623,  3.89447236,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.84147098,  0.86503801,  0.88683599,  0.90682034,  0.92495019,
#         0.94118847,  0.95550197,  0.96786141,  0.97824152,  0.98662108,
#         0.99298295,  0.99731411,  0.99960571,  0.99985306,  0.99805565,
#         0.99421717,  0.98834546,  0.98045253,  0.97055453,  0.95867168,
#         0.9448283 ,  0.9290527 ,  0.91137713,  0.89183774,  0.8704745 ,
#         0.84733109,  0.82245485,  0.79589664,  0.76771077,  0.7379549 ,
#         0.70668987,  0.67397962,  0.63989104,  0.60449386,  0.56786045,
#         0.53006573,  0.491187  ,  0.45130377,  0.4104976 ,  0.36885193,
#         0.32645195,  0.28338435,  0.23973722,  0.19559981,  0.15106239,
#         0.10621603,  0.06115246,  0.01596383, -0.02925744, -0.07441889,
#        -0.11942814, -0.16419316, -0.20862239, -0.25262498, -0.29611093,
#        -0.33899133, -0.38117846, -0.42258607, -0.46312947, -0.50272574,
#        -0.54129391, -0.5787551 , -0.61503271, -0.65005254, -0.68374298,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is x label data")
plt.ylabel("This is y label data")
plt.title("This is title")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)

plt.scatter(x,y, c=colors, alpha= .5)
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("Random Data")
plt.show()

# %%
a = ["a", "b", "c", "d", "e"]
b = np.random.randint(1,10, 5)

plt.bar(a,b)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Bar Plot")
plt.show()

# %%
a = ["a", "b", "c", "d", "e"]
b = np.random.randint(1,10, 5)

plt.barh(a,b)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Bar Plot")
plt.show()

# %%
x = np.linspace(1,10, 200)
y = np.sin(x)

plt.figure(figsize=(8,2))
plt.xlabel("X label")
plt.ylabel("Y label")
plt.plot(x,y, "--b", marker='')
plt.grid()
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x,y, c='b', alpha= .5, s=100, marker='x')
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("Random Data")
plt.show()

# %%
data = [1,2,3,4,5,6,7,8,2,3,5,1,2,6,7,3,4]

plt.hist(data)
# Out:
# (array([2., 3., 3., 0., 2., 2., 0., 2., 2., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.randint(10, 15, 50)
y = np.random.randint(10, 15, 50)
z = np.random.randint(10, 15, 50)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = "3d")
ax.scatter(x,y,z)

# %% [markdown]
# # pyplot
#
# `matplotlib.pyplot` is a collection of functions that makes matplotlib work like MATLAB. Each `pyplot` function makes some change to a figure: eg., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
plt.plot([1,2,3,4])
plt.ylabel('Some numbers')
plt.show()

# %% [markdown]
# ## Formatting the style of your plot
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The default format string is 'b-', which is a solid blue line. For example, to plot the above with red circles, you would issue

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis((0,6,0,20))
plt.show()

# %%
t = np.arange(0., 5., 0.2)

# reddashes, blue squars and green trainagles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ## Plotting with keyword strings

# %%
plt.plot(range(10), '--b>', label='line with marker')
plt.legend()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()
