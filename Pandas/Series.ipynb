# %% [markdown]
# # Series
#
# `Series:` One dimensional ndarray with axis labels (including time series).

# %%
# firstly import numpy and pandas 
import numpy as np
import pandas as pd

# %%
# read_csv function is used to read the csv file.
df = pd.read_csv("../Dataset/Life Expectancy Data.csv")

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
# head method in dataframe used to get top 5 rows
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### pandas size method
# The size property is used to get an int representing the number of elements in this object and Return the number of rows if Series. Otherwise, return the number of rows times the number of columns if DataFrame.

# %%
df.size
# Out:
# 64636

# %%
# shape mmethod returns the dimension of dataframe rows & columns
df.shape
# Out:
# (2938, 22)

# %% [markdown]
# ### pandas info method
#
# info method returns the infromation about dataframe
# The information contains the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %% [markdown]
# ## Creating a series

# %%
# creating a series with list
series_list = ("Abhishek", "Sunny", "Manish", "Hanish", "Anuj", "Mayank", "Sarjeet", "Diljeet", "Arpit", "Monu")

l_series = pd.Series(series_list)

l_series
# Out:
# 0    Abhishek
# 1       Sunny
# 2      Manish
# 3      Hanish
# 4        Anuj
# 5      Mayank
# 6     Sarjeet
# 7     Diljeet
# 8       Arpit
# 9        Monu
# dtype: object

# %%
# creating a series with dictionary
_dict = {"Abhishek": 19, "Sunny": 19, "Manish": 20, "Hanish": 19, "Anuj": 22, "Mayank":19, "Sarjeet":20, "Diljeet":25, "Arpit":18, "Monu":26}

d_series = pd.Series(_dict)

d_series
# Out:
# Abhishek    19
# Sunny       19
# Manish      20
# Hanish      19
# Anuj        22
# Mayank      19
# Sarjeet     20
# Diljeet     25
# Arpit       18
# Monu        26
# dtype: int64

# %%
"""
Creating a Series with tuple
we can only create a series with only array-like object, dicttionary, iterable object or a scalar value. so we can also create a series by passing the tuple.
"""

_tuple = (("Abhishek", 19), ("Sunny", 19), ("Manish", 20), ("Hanish", 19), ("Aunj", 22))

t_series = pd.Series(_tuple)

t_series
# Out:
# 0    (Abhishek, 19)
# 1       (Sunny, 19)
# 2      (Manish, 20)
# 3      (Hanish, 19)
# 4        (Aunj, 22)
# dtype: object

# %% [markdown]
# `Note:`  In this result values ar the pair of the name and the age together which can be useful some time but it would be better if all the names treated as the index values. For that we need to convert this tuple in the dict object.

# %%
t_series = pd.Series(data = dict(_tuple))

t_series
# Out:
# Abhishek    19
# Sunny       19
# Manish      20
# Hanish      19
# Aunj        22
# dtype: int64

# %% [markdown]
# # Mostly used attributes in Series
# - array: The ExtensionArray of the data backing this Series or Index.

# %% [markdown]
# #### Creating a series

# %%
_rs = np.random.randint(50, size=50)

_ps = pd.Series(_rs)

for i in range(10):
    _ps[np.random.randint(0,49,)] = np.nan 

_ps
# Out:
# 0     29.0
# 1     20.0
# 2      0.0
# 3     37.0
# 4     24.0
# 5     12.0
# 6     40.0
# 7     23.0
# 8     18.0
# 9     23.0
# 10     NaN
# 11     0.0
# 12     0.0
# 13    10.0
# 14    32.0
# 15     NaN
# 16     6.0
# 17     1.0
# 18     4.0
# 19     NaN
# 20    30.0
# 21     NaN
# 22    17.0
# 23    27.0
# 24    21.0
# 25    35.0
# 26     NaN
# 27     NaN
# 28    46.0
# 29    20.0
# 30     2.0
# 31    26.0
# 32     0.0
# 33    10.0
# 34     NaN
# 35     NaN
# 36     0.0
# 37    37.0
# 38    39.0
# 39     NaN
# 40     4.0
# 41    27.0
# 42     NaN
# 43    33.0
# 44    41.0
# 45    48.0
# 46    49.0
# 47    30.0
# 48    11.0
# 49    21.0
# dtype: float64

# %% [markdown]
# Noew we have a randomly generated series with some `NaN` not a number values, now we will work on some pandas series attributes.
#
# `Note:` Here **Nan**(not a number) is the standard missing data marker used in pandas.

# %% [markdown]
# #### 1. array - attribute
#
# The ExtensionArray of the data backing this series or index.
#
#    Pandas series object have a .array attribute that can be used to acess the underlying array of data for a series object. This can be useful for working with data in a Series, but can also lead to problems if the underlying array contains different data types. To avoid this, it is important to ensure that the data types in the underlying array are all the same. Additionally, the .array attribute can be used to create a new Series object from an exisiting array.

# %%
# getting the array form the serie
_ps.array
# Out:
# <PandasArray>
# [29.0, 20.0,  0.0, 37.0, 24.0, 12.0, 40.0, 23.0, 18.0, 23.0,  nan,  0.0,  0.0,
#  10.0, 32.0,  nan,  6.0,  1.0,  4.0,  nan, 30.0,  nan, 17.0, 27.0, 21.0, 35.0,
#   nan,  nan, 46.0, 20.0,  2.0, 26.0,  0.0, 10.0,  nan,  nan,  0.0, 37.0, 39.0,
#   nan,  4.0, 27.0,  nan, 33.0, 41.0, 48.0, 49.0, 30.0, 11.0, 21.0]
# Length: 50, dtype: float64

# %%
df_year = df["Year"]
df_year.array
# Out:
# <PandasArray>
# [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006,
#  ...
#  2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000]
# Length: 2938, dtype: int64

# %% [markdown]
# `Note: ` If we want to work on the pure numpy array than we need to use the `Series.to_numpy()` method.

# %%
_ps.to_numpy()
# Out:
# array([29., 20.,  0., 37., 24., 12., 40., 23., 18., 23., nan,  0.,  0.,
#        10., 32., nan,  6.,  1.,  4., nan, 30., nan, 17., 27., 21., 35.,
#        nan, nan, 46., 20.,  2., 26.,  0., 10., nan, nan,  0., 37., 39.,
#        nan,  4., 27., nan, 33., 41., 48., 49., 30., 11., 21.])

# %% [markdown]
# #### axes - attribute
#
# Pandas `Series.axes` is an attribute that contains a list of the row and columns axes labels of the series. If the row and columns axes have different labels, then the Series.axes attribute will include both labels. Problems with Series.axes attribute can arise if the labels of the rows and columns axes are not properly set. To solve this issue, you can use the `Series.renameaxis()` method to correctly set the labels of the axes. Additionally, you can use the `series.restindex()` method to reset the index of the series, which will also reset the labels of the axes.

# %%
_ps.axes
# Out:
# [RangeIndex(start=0, stop=50, step=1)]

# %%
df_year.axes
# Out:
# [RangeIndex(start=0, stop=2938, step=1)]

# %% [markdown]
# #### index - attribute
# - The index (axis labels) of the series.

# %%
_ps.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df_year.index
# Out:
# RangeIndex(start=0, stop=2938, step=1)

# %% [markdown]
# #### values - attribute
# - Return series as ndarray or ndarray-like depending on the dtype.

# %%
_ps.values
# Out:
# array([29., 20.,  0., 37., 24., 12., 40., 23., 18., 23., nan,  0.,  0.,
#        10., 32., nan,  6.,  1.,  4., nan, 30., nan, 17., 27., 21., 35.,
#        nan, nan, 46., 20.,  2., 26.,  0., 10., nan, nan,  0., 37., 39.,
#        nan,  4., 27., nan, 33., 41., 48., 49., 30., 11., 21.])

# %%
df_year.values
# Out:
# array([2015, 2014, 2013, ..., 2002, 2001, 2000], dtype=int64)

# %% [markdown]
# As a pandas documentation we should avoid to use `Series.values` instead we should use `Series.array` or `Series_tonumpy()` method.

# %% [markdown]
# #### dtype and dtypes - attribute
# - both dtype and dtypes Return the dtype object of the underlying data

# %%
_ps.dtype
# Out:
# dtype('float64')

# %%
df_year.dtype
# Out:
# dtype('int64')

# %%
_ps.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# #### shape - attribute
# - Return a tuple of the shape of the underlying data.
# - in simple words no. of columns & no. of rows
# - in series they returns no. of columns

# %%
_ps.shape
# Out:
# (50,)

# %%
df_year.shape
# Out:
# (2938,)

# %% [markdown]
# #### nbytes - attribute
# - Returns the number of bytes in the underlying data.

# %%
_ps.nbytes
# Out:
# 400

# %% [markdown]
# As we can see that we have got 400 bytes consumed by this series. we have 50 items inside this series and each of them 8-bytes since they are float64 dtype values.

# %%
df_year.nbytes
# Out:
# 23504

# %% [markdown]
# #### size - attribute
# - Returns the number of elements in the underlying data.
# - in simple words in series they return no. of columns in a series

# %%
_ps.size
# Out:
# 50

# %%
df_year.size
# Out:
# 2938

# %% [markdown]
# #### T - attribute
# - Return the transpose, which is by definition self.

# %%
_ps.T
# Out:
# 0     29.0
# 1     20.0
# 2      0.0
# 3     37.0
# 4     24.0
# 5     12.0
# 6     40.0
# 7     23.0
# 8     18.0
# 9     23.0
# 10     NaN
# 11     0.0
# 12     0.0
# 13    10.0
# 14    32.0
# 15     NaN
# 16     6.0
# 17     1.0
# 18     4.0
# 19     NaN
# 20    30.0
# 21     NaN
# 22    17.0
# 23    27.0
# 24    21.0
# 25    35.0
# 26     NaN
# 27     NaN
# 28    46.0
# 29    20.0
# 30     2.0
# 31    26.0
# 32     0.0
# 33    10.0
# 34     NaN
# 35     NaN
# 36     0.0
# 37    37.0
# 38    39.0
# 39     NaN
# 40     4.0
# 41    27.0
# 42     NaN
# 43    33.0
# 44    41.0
# 45    48.0
# 46    49.0
# 47    30.0
# 48    11.0
# 49    21.0
# dtype: float64

# %%
df_year.T
# Out:
# 0       2015
# 1       2014
# 2       2013
# 3       2012
# 4       2011
#         ...
# 2933    2004
# 2934    2003
# 2935    2002
# 2936    2001
# 2937    2000
# Name: Year, Length: 2938, dtype: int64

# %%
df.T
# Out:
#                                         0            1            2     \
# Country                          Afghanistan  Afghanistan  Afghanistan
# Year                                    2015         2014         2013
# Status                            Developing   Developing   Developing
# Life expectancy                         65.0         59.9         59.9
# Adult Mortality                        263.0        271.0        268.0
# infant deaths                             62           64           66
# Alcohol                                 0.01         0.01         0.01
# percentage expenditure             71.279624    73.523582    73.219243
# Hepatitis B                             65.0         62.0         64.0
# Measles                                 1154          492          430
#  BMI                                    19.1         18.6         18.1
# under-five deaths                         83           86           89
# Polio                                    6.0         58.0         62.0
# Total expenditure                       8.16         8.18         8.13
# Diphtheria                              65.0         62.0         64.0
#  HIV/AIDS                                0.1          0.1          0.1
# GDP                                584.25921   612.696514   631.744976
# Population                        33736494.0     327582.0   31731688.0
#  thinness  1-19 years                   17.2         17.5         17.7
#  thinness 5-9 years                     17.3         17.5         17.7
# Income composition of resources        0.479        0.476         0.47
# Schooling                               10.1         10.0          9.9
#
#                                         3            4            5     \
# Country                          Afghanistan  Afghanistan  Afghanistan
# Year                                    2012         2011         2010
# Status                            Developing   Developing   Developing
# Life expectancy                         59.5         59.2         58.8
# Adult Mortality                        272.0        275.0        279.0
# infant deaths                             69           71           74
# Alcohol                                 0.01         0.01         0.01
# percentage expenditure             78.184215     7.097109    79.679367
# Hepatitis B                             67.0         68.0         66.0
# Measles                                 2787         3013         1989
#  BMI                                    17.6         17.2         16.7
# under-five deaths                         93           97          102
# Polio                                   67.0         68.0         66.0
# Total expenditure                       8.52         7.87          9.2
# Diphtheria                              67.0         68.0         66.0
#  HIV/AIDS                                0.1          0.1          0.1
# GDP                                  669.959    63.537231    553.32894
# Population                         3696958.0    2978599.0    2883167.0
#  thinness  1-19 years                   17.9         18.2         18.4
#  thinness 5-9 years                     18.0         18.2         18.4
# Income composition of resources        0.463        0.454        0.448
# Schooling                                9.8          9.5          9.2
#
#                                         6            7            8     \
# Country                          Afghanistan  Afghanistan  Afghanistan
# Year                                    2009         2008         2007
# Status                            Developing   Developing   Developing
# Life expectancy                         58.6         58.1         57.5
# Adult Mortality                        281.0        287.0        295.0
# infant deaths                             77           80           82
# Alcohol                                 0.01         0.03         0.02
# percentage expenditure             56.762217    25.873925    10.910156
# Hepatitis B                             63.0         64.0         63.0
# Measles                                 2861         1599         1141
#  BMI                                    16.2         15.7         15.2
# under-five deaths                        106          110          113
# Polio                                   63.0         64.0         63.0
# Total expenditure                       9.42         8.33         6.73
# Diphtheria                              63.0         64.0         63.0
#  HIV/AIDS                                0.1          0.1          0.1
# GDP                               445.893298   373.361116   369.835796
# Population                          284331.0    2729431.0   26616792.0
#  thinness  1-19 years                   18.6         18.8         19.0
#  thinness 5-9 years                     18.7         18.9         19.1
# Income composition of resources        0.434        0.433        0.415
# Schooling                                8.9          8.7          8.4
#
#                                         9     ...        2928        2929  \
# Country                          Afghanistan  ...    Zimbabwe    Zimbabwe
# Year                                    2006  ...        2009        2008
# Status                            Developing  ...  Developing  Developing
# Life expectancy                         57.3  ...        50.0        48.2
# Adult Mortality                        295.0  ...       587.0       632.0
# infant deaths                             84  ...          30          30
# Alcohol                                 0.03  ...        4.64        3.56
# percentage expenditure             17.171518  ...    1.040021   20.843429
# Hepatitis B                             64.0  ...        73.0        75.0
# Measles                                 1990  ...         853           0
#  BMI                                    14.7  ...        29.0        28.6
# under-five deaths                        116  ...          45          46
# Polio                                   58.0  ...        69.0        75.0
# Total expenditure                       7.43  ...        6.26        4.96
# Diphtheria                              58.0  ...        73.0        75.0
#  HIV/AIDS                                0.1  ...        18.1        20.5
# GDP                                272.56377  ...   65.824121  325.678573
# Population                         2589345.0  ...   1381599.0  13558469.0
#  thinness  1-19 years                   19.2  ...         7.5         7.8
#  thinness 5-9 years                     19.3  ...         7.4         7.8
# Income composition of resources        0.405  ...       0.419       0.421
# Schooling                                8.1  ...         9.9         9.7
#
#                                        2930        2931        2932  \
# Country                            Zimbabwe    Zimbabwe    Zimbabwe
# Year                                   2007        2006        2005
# Status                           Developing  Developing  Developing
# Life expectancy                        46.6        45.4        44.6
# Adult Mortality                        67.0         7.0       717.0
# infant deaths                            29          28          28
# Alcohol                                3.88        4.57        4.14
# percentage expenditure            29.814566   34.262169    8.717409
# Hepatitis B                            72.0        68.0        65.0
# Measles                                 242         212         420
#  BMI                                   28.2        27.9        27.5
# under-five deaths                        46          45          43
# Polio                                  73.0        71.0        69.0
# Total expenditure                      4.47        5.12        6.44
# Diphtheria                             73.0         7.0        68.0
#  HIV/AIDS                              23.7        26.8        30.3
# GDP                              396.998217  414.796232   444.76575
# Population                        1332999.0  13124267.0    129432.0
#  thinness  1-19 years                   8.2         8.6         9.0
#  thinness 5-9 years                     8.2         8.6         9.0
# Income composition of resources       0.414       0.408       0.406
# Schooling                               9.6         9.5         9.3
#
#                                        2933        2934        2935  \
# Country                            Zimbabwe    Zimbabwe    Zimbabwe
# Year                                   2004        2003        2002
# Status                           Developing  Developing  Developing
# Life expectancy                        44.3        44.5        44.8
# Adult Mortality                       723.0       715.0        73.0
# infant deaths                            27          26          25
# Alcohol                                4.36        4.06        4.43
# percentage expenditure                  0.0         0.0         0.0
# Hepatitis B                            68.0         7.0        73.0
# Measles                                  31         998         304
#  BMI                                   27.1        26.7        26.3
# under-five deaths                        42          41          40
# Polio                                  67.0         7.0        73.0
# Total expenditure                      7.13        6.52        6.53
# Diphtheria                             65.0        68.0        71.0
#  HIV/AIDS                              33.6        36.7        39.8
# GDP                              454.366654  453.351155    57.34834
# Population                       12777511.0  12633897.0    125525.0
#  thinness  1-19 years                   9.4         9.8         1.2
#  thinness 5-9 years                     9.4         9.9         1.3
# Income composition of resources       0.407       0.418       0.427
# Schooling                               9.2         9.5        10.0
#
#                                        2936        2937
# Country                            Zimbabwe    Zimbabwe
# Year                                   2001        2000
# Status                           Developing  Developing
# Life expectancy                        45.3        46.0
# Adult Mortality                       686.0       665.0
# infant deaths                            25          24
# Alcohol                                1.72        1.68
# percentage expenditure                  0.0         0.0
# Hepatitis B                            76.0        79.0
# Measles                                 529        1483
#  BMI                                   25.9        25.5
# under-five deaths                        39          39
# Polio                                  76.0        78.0
# Total expenditure                      6.16         7.1
# Diphtheria                             75.0        78.0
#  HIV/AIDS                              42.1        43.5
# GDP                              548.587312  547.358878
# Population                       12366165.0  12222251.0
#  thinness  1-19 years                   1.6        11.0
#  thinness 5-9 years                     1.7        11.2
# Income composition of resources       0.427       0.434
# Schooling                               9.8         9.8
#
# [22 rows x 2938 columns]

# %% [markdown]
# #### memory_usage - method
# - Returns the memory usage of the Series

# %%
_ps.memory_usage()
# Out:
# 528

# %%
df_year.memory_usage()
# Out:
# 23632

# %% [markdown]
# `note: ` Not including the index gives the size of the rest of the data, which is necessarily smaller:

# %%
df_year.memory_usage(index=False)
# Out:
# 23504

# %%
_ps.memory_usage(index=False)
# Out:
# 400

# %% [markdown]
# `note: ` The memory footprint of object values is ignored by default:

# %%
_ps.memory_usage(deep=True)
# Out:
# 528

# %% [markdown]
# #### hasnans - attribute
# - Return true if there are any NaN values present inside the series.

# %%
_ps.hasnans
# Out:
# True

# %%
df_year.to_numpy()
# Out:
# array([2015, 2014, 2013, ..., 2002, 2001, 2000], dtype=int64)

# %%
df_year.hasnans
# Out:
# False

# %% [markdown]
# #### empty - attribute
# - Indicator whether Series/DataFrame is empty.

# %%
_ps.empty
# Out:
# False

# %%
df.empty
# Out:
# False

# %%
df_year.empty
# Out:
# False

# %% [markdown]
# #### dtype - attribute
# - Returns the dtype object of the underlying data.

# %%
df_year.dtype
# Out:
# dtype('int64')

# %%
_ps.dtype
# Out:
# dtype('float64')

# %%
df["Country"].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### name - attribute
# Returns the name of the series

# %%
df_year.name
# Out:
# 'Year'

# %% [markdown]
# ## Conversion

# %% [markdown]
# #### convert_dtypes() - attribute
# - Convert columns to the best possible dtypes using dtypes supporting.

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
dfc = df.convert_dtypes()
dfc.dtypes
# Out:
# Country                            string[python]
# Year                                        Int64
# Status                             string[python]
# Life expectancy                           Float64
# Adult Mortality                             Int64
# infant deaths                               Int64
# Alcohol                                   Float64
# percentage expenditure                    Float64
# Hepatitis B                                 Int64
# Measles                                     Int64
#  BMI                                      Float64
# under-five deaths                           Int64
# Polio                                       Int64
# Total expenditure                         Float64
# Diphtheria                                  Int64
#  HIV/AIDS                                 Float64
# GDP                                       Float64
# Population                                Float64
#  thinness  1-19 years                     Float64
#  thinness 5-9 years                       Float64
# Income composition of resources           Float64
# Schooling                                 Float64
# dtype: object

# %% [markdown]
# #### copy - attribute
# - Make a copy of this objects indices and data.

# %%
df_year_c = df_year.copy

# %%
df_year_c
# Out:
# <bound method NDFrame.copy of 0       2015
# 1       2014
# 2       2013
# 3       2012
# 4       2011
#         ...
# 2933    2004
# 2934    2003
# 2935    2002
# 2936    2001
# 2937    2000
# Name: Year, Length: 2938, dtype: int64>

# %% [markdown]
# #### bool - attribute
# Returns the bool of a single element Series or DataFrame.

# %%
_boll_c = pd.Series([True]).bool()

# %%
_boll_c
# Out:
# True

# %%
df_year.astype('int32').dtypes
# Out:
# dtype('int32')

# %%
df_year.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #### to.numpy - attribute
# A NumPy ndarray representing the values in this Series or Index.

# %%
_ps.to_numpy
# Out:
# <bound method IndexOpsMixin.to_numpy of 0     29.0
# 1     20.0
# 2      0.0
# 3     37.0
# 4     24.0
# 5     12.0
# 6     40.0
# 7     23.0
# 8     18.0
# 9     23.0
# 10     NaN
# 11     0.0
# 12     0.0
# 13    10.0
# 14    32.0
# 15     NaN
# 16     6.0
# 17     1.0
# 18     4.0
# 19     NaN
# 20    30.0
# 21     NaN
# 22    17.0
# 23    27.0
# 24    21.0
# 25    35.0
# 26     NaN
# 27     NaN
# 28    46.0
# 29    20.0
# 30     2.0
# 31    26.0
# 32     0.0
# 33    10.0
# 34     NaN
# 35     NaN
# 36     0.0
# 37    37.0
# 38    39.0
# 39     NaN
# 40     4.0
# 41    27.0
# 42     NaN
# 43    33.0
# 44    41.0
# 45    48.0
# 46    49.0
# 47    30.0
# 48    11.0
# 49    21.0
# dtype: float64>

# %%
df_year.to_numpy
# Out:
# <bound method IndexOpsMixin.to_numpy of 0       2015
# 1       2014
# 2       2013
# 3       2012
# 4       2011
#         ...
# 2933    2004
# 2934    2003
# 2935    2002
# 2936    2001
# 2937    2000
# Name: Year, Length: 2938, dtype: int64>

# %%
df_year.__array__
# Out:
# <bound method Series.__array__ of 0       2015
# 1       2014
# 2       2013
# 3       2012
# 4       2011
#         ...
# 2933    2004
# 2934    2003
# 2935    2002
# 2936    2001
# 2937    2000
# Name: Year, Length: 2938, dtype: int64>

# %% [markdown]
# ## Indexing, iterations

# %% [markdown]
# #### get(key) - method
# - Get item from object for given key

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.get(["Country", "Year", "Life expectancy", "BMI", "Alcohol", "Schooling"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.columns = [x.strip() for x in df.columns]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
BMI = df["Country"]
BMI.get("India")

# %%
# df["Country"].unique()

# %% [markdown]
# #### at() & iat() - method
# `Series.at() ` Access a single value for a row/column lable pair.
# `Series.iat() ` Access a single value for a row/column pair by integer position.

# %%
_dict
# Out:
# {'Abhishek': 19,
#  'Sunny': 19,
#  'Manish': 20,
#  'Hanish': 19,
#  'Anuj': 22,
#  'Mayank': 19,
#  'Sarjeet': 20,
#  'Diljeet': 25,
#  'Arpit': 18,
#  'Monu': 26}

# %%
ds = pd.Series(data=_dict, name="Student", dtype=np.int8)

# %%
ds
# Out:
# Abhishek    19
# Sunny       19
# Manish      20
# Hanish      19
# Anuj        22
# Mayank      19
# Sarjeet     20
# Diljeet     25
# Arpit       18
# Monu        26
# Name: Student, dtype: int8

# %%
# we can access any value by its label name.
ds.at["Mayank"]
# Out:
# 19

# %% [markdown]
# if we want to access the value by its index number then also we can use the `Series.iat()` method instead of using the `Series.at()` method.

# %%
ds.iat[6]
# Out:
# 20

# %%
df_year.shape
# Out:
# (2938,)

# %% [markdown]
# #### pop - method
# - Return item and drop from series.

# %%
df_year.pop(2937)
# Out:
# 2000

# %%
df_year.shape
# Out:
# (2937,)

# %%
df_country = df

# %%
df_country
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       Population  thinness  1-19 years  thinness 5-9 years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
df_country.set_index("Country", inplace=True)

# %%
df_country.loc["Afghanistan":"Argentina"]
# Out:
#              Year      Status  Life expectancy  Adult Mortality  \
# Country
# Afghanistan  2015  Developing             65.0            263.0
# Afghanistan  2014  Developing             59.9            271.0
# Afghanistan  2013  Developing             59.9            268.0
# Afghanistan  2012  Developing             59.5            272.0
# Afghanistan  2011  Developing             59.2            275.0
# ...           ...         ...              ...              ...
# Argentina    2004  Developing             74.7             13.0
# Argentina    2003  Developing             74.1            137.0
# Argentina    2002  Developing             74.1            138.0
# Argentina    2001  Developing             74.0            138.0
# Argentina    2000  Developing             74.1            137.0
#
#              infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country
# Afghanistan             62     0.01               71.279624         65.0
# Afghanistan             64     0.01               73.523582         62.0
# Afghanistan             66     0.01               73.219243         64.0
# Afghanistan             69     0.01               78.184215         67.0
# Afghanistan             71     0.01                7.097109         68.0
# ...                    ...      ...                     ...          ...
# Argentina               11     7.63              719.366380         81.0
# Argentina               11     7.62               57.584674         73.0
# Argentina               12     7.81              470.186915         66.0
# Argentina               12     7.76              123.012867          NaN
# Argentina               12     7.68             1349.025282          NaN
#
#              Measles   BMI  ...  Polio  Total expenditure  Diphtheria  \
# Country                     ...
# Afghanistan     1154  19.1  ...    6.0               8.16        65.0
# Afghanistan      492  18.6  ...   58.0               8.18        62.0
# Afghanistan      430  18.1  ...   62.0               8.13        64.0
# Afghanistan     2787  17.6  ...   67.0               8.52        67.0
# Afghanistan     3013  17.2  ...   68.0               7.87        68.0
# ...              ...   ...  ...    ...                ...         ...
# Argentina          0  56.3  ...   91.0               6.84        98.0
# Argentina          0  55.7  ...   95.0               8.22        96.0
# Argentina          0  55.1  ...   94.0               8.31        93.0
# Argentina          0  54.6  ...   85.0               9.38        83.0
# Argentina          6  54.0  ...   88.0               9.21        83.0
#
#              HIV/AIDS          GDP  Population  thinness  1-19 years  \
# Country
# Afghanistan       0.1   584.259210  33736494.0                  17.2
# Afghanistan       0.1   612.696514    327582.0                  17.5
# Afghanistan       0.1   631.744976  31731688.0                  17.7
# Afghanistan       0.1   669.959000   3696958.0                  17.9
# Afghanistan       0.1    63.537231   2978599.0                  18.2
# ...               ...          ...         ...                   ...
# Argentina         0.1  4251.574348  38728696.0                   1.1
# Argentina         0.1   333.437600   3839379.0                   1.2
# Argentina         0.1  2579.193168   3788937.0                   1.2
# Argentina         0.1   717.694674   3747159.0                   1.2
# Argentina         0.1  7669.273916   3757452.0                   1.2
#
#              thinness 5-9 years  Income composition of resources  Schooling
# Country
# Afghanistan                17.3                            0.479       10.1
# Afghanistan                17.5                            0.476       10.0
# Afghanistan                17.7                            0.470        9.9
# Afghanistan                18.0                            0.463        9.8
# Afghanistan                18.2                            0.454        9.5
# ...                         ...                              ...        ...
# Argentina                   1.0                            0.775       16.3
# Argentina                   1.0                            0.770       16.4
# Argentina                   1.0                            0.776       16.3
# Argentina                   1.1                            0.771       15.6
# Argentina                   1.1                            0.764       15.0
#
# [96 rows x 21 columns]

# %%
df_country.iloc[6:20]
# Out:
#              Year      Status  Life expectancy  Adult Mortality  \
# Country
# Afghanistan  2009  Developing             58.6            281.0
# Afghanistan  2008  Developing             58.1            287.0
# Afghanistan  2007  Developing             57.5            295.0
# Afghanistan  2006  Developing             57.3            295.0
# Afghanistan  2005  Developing             57.3            291.0
# Afghanistan  2004  Developing             57.0            293.0
# Afghanistan  2003  Developing             56.7            295.0
# Afghanistan  2002  Developing             56.2              3.0
# Afghanistan  2001  Developing             55.3            316.0
# Afghanistan  2000  Developing             54.8            321.0
# Albania      2015  Developing             77.8             74.0
# Albania      2014  Developing             77.5              8.0
# Albania      2013  Developing             77.2             84.0
# Albania      2012  Developing             76.9             86.0
#
#              infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country
# Afghanistan             77     0.01               56.762217         63.0
# Afghanistan             80     0.03               25.873925         64.0
# Afghanistan             82     0.02               10.910156         63.0
# Afghanistan             84     0.03               17.171518         64.0
# Afghanistan             85     0.02                1.388648         66.0
# Afghanistan             87     0.02               15.296066         67.0
# Afghanistan             87     0.01               11.089053         65.0
# Afghanistan             88     0.01               16.887351         64.0
# Afghanistan             88     0.01               10.574728         63.0
# Afghanistan             88     0.01               10.424960         62.0
# Albania                  0     4.60              364.975229         99.0
# Albania                  0     4.51              428.749067         98.0
# Albania                  0     4.76              430.876979         99.0
# Albania                  0     5.14              412.443356         99.0
#
#              Measles   BMI  ...  Polio  Total expenditure  Diphtheria  \
# Country                     ...
# Afghanistan     2861  16.2  ...   63.0               9.42        63.0
# Afghanistan     1599  15.7  ...   64.0               8.33        64.0
# Afghanistan     1141  15.2  ...   63.0               6.73        63.0
# Afghanistan     1990  14.7  ...   58.0               7.43        58.0
# Afghanistan     1296  14.2  ...   58.0               8.70        58.0
# Afghanistan      466  13.8  ...    5.0               8.79         5.0
# Afghanistan      798  13.4  ...   41.0               8.82        41.0
# Afghanistan     2486  13.0  ...   36.0               7.76        36.0
# Afghanistan     8762  12.6  ...   35.0               7.80        33.0
# Afghanistan     6532  12.2  ...   24.0               8.20        24.0
# Albania            0  58.0  ...   99.0               6.00        99.0
# Albania            0  57.2  ...   98.0               5.88        98.0
# Albania            0  56.5  ...   99.0               5.66        99.0
# Albania            9  55.8  ...   99.0               5.59        99.0
#
#              HIV/AIDS          GDP  Population  thinness  1-19 years  \
# Country
# Afghanistan       0.1   445.893298    284331.0                  18.6
# Afghanistan       0.1   373.361116   2729431.0                  18.8
# Afghanistan       0.1   369.835796  26616792.0                  19.0
# Afghanistan       0.1   272.563770   2589345.0                  19.2
# Afghanistan       0.1    25.294130    257798.0                  19.3
# Afghanistan       0.1   219.141353  24118979.0                  19.5
# Afghanistan       0.1   198.728544   2364851.0                  19.7
# Afghanistan       0.1   187.845950  21979923.0                  19.9
# Afghanistan       0.1   117.496980   2966463.0                   2.1
# Afghanistan       0.1   114.560000    293756.0                   2.3
# Albania           0.1  3954.227830     28873.0                   1.2
# Albania           0.1  4575.763787    288914.0                   1.2
# Albania           0.1  4414.723140    289592.0                   1.3
# Albania           0.1  4247.614380      2941.0                   1.3
#
#              thinness 5-9 years  Income composition of resources  Schooling
# Country
# Afghanistan                18.7                            0.434        8.9
# Afghanistan                18.9                            0.433        8.7
# Afghanistan                19.1                            0.415        8.4
# Afghanistan                19.3                            0.405        8.1
# Afghanistan                19.5                            0.396        7.9
# Afghanistan                19.7                            0.381        6.8
# Afghanistan                19.9                            0.373        6.5
# Afghanistan                 2.2                            0.341        6.2
# Afghanistan                 2.4                            0.340        5.9
# Afghanistan                 2.5                            0.338        5.5
# Albania                     1.3                            0.762       14.2
# Albania                     1.3                            0.761       14.2
# Albania                     1.4                            0.759       14.2
# Albania                     1.4                            0.752       14.2
#
# [14 rows x 21 columns]

# %% [markdown]
# # Missing Data Handling

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df["Life expectancy"].isnull().sum()
# Out:
# 10

# %%
df_null =  df[["Country","Alcohol", "Hepatitis B", "Total expenditure", "GDP", "Population","Income composition of resources", "Schooling"]]

# %%
df_null
# Out:
#           Country  Alcohol  Hepatitis B  Total expenditure         GDP  \
# 0     Afghanistan     0.01         65.0               8.16  584.259210
# 1     Afghanistan     0.01         62.0               8.18  612.696514
# 2     Afghanistan     0.01         64.0               8.13  631.744976
# 3     Afghanistan     0.01         67.0               8.52  669.959000
# 4     Afghanistan     0.01         68.0               7.87   63.537231
# ...           ...      ...          ...                ...         ...
# 2933     Zimbabwe     4.36         68.0               7.13  454.366654
# 2934     Zimbabwe     4.06          7.0               6.52  453.351155
# 2935     Zimbabwe     4.43         73.0               6.53   57.348340
# 2936     Zimbabwe     1.72         76.0               6.16  548.587312
# 2937     Zimbabwe     1.68         79.0               7.10  547.358878
#
#       Population  Income composition of resources  Schooling
# 0     33736494.0                            0.479       10.1
# 1       327582.0                            0.476       10.0
# 2     31731688.0                            0.470        9.9
# 3      3696958.0                            0.463        9.8
# 4      2978599.0                            0.454        9.5
# ...          ...                              ...        ...
# 2933  12777511.0                            0.407        9.2
# 2934  12633897.0                            0.418        9.5
# 2935    125525.0                            0.427       10.0
# 2936  12366165.0                            0.427        9.8
# 2937  12222251.0                            0.434        9.8
#
# [2938 rows x 8 columns]

# %%
null_value_index = df_null[df_null.Alcohol.isnull()].index
df_null[df_null.Alcohol.isnull()]
# Out:
#                                  Country  Alcohol  Hepatitis B  \
# 32                               Algeria      NaN         95.0
# 48                                Angola      NaN         64.0
# 64                   Antigua and Barbuda      NaN         99.0
# 80                             Argentina      NaN         94.0
# 96                               Armenia      NaN         94.0
# ...                                  ...      ...          ...
# 2858  Venezuela (Bolivarian Republic of)      NaN         87.0
# 2874                            Viet Nam      NaN         97.0
# 2890                               Yemen      NaN         69.0
# 2906                              Zambia      NaN          9.0
# 2922                            Zimbabwe      NaN         87.0
#
#       Total expenditure           GDP  Population  \
# 32                  NaN   4132.762920  39871528.0
# 48                  NaN   3695.793748   2785935.0
# 64                  NaN  13566.954100         NaN
# 80                  NaN  13467.123600  43417765.0
# 96                  NaN    369.654776    291695.0
# ...                 ...           ...         ...
# 2858                NaN           NaN         NaN
# 2874                NaN           NaN         NaN
# 2890                NaN           NaN         NaN
# 2906                NaN   1313.889646    161587.0
# 2922                NaN    118.693830  15777451.0
#
#       Income composition of resources  Schooling
# 32                              0.743       14.4
# 48                              0.531       11.4
# 64                              0.784       13.9
# 80                              0.826       17.3
# 96                              0.741       12.7
# ...                               ...        ...
# 2858                            0.769       14.3
# 2874                            0.678       12.6
# 2890                            0.499        9.0
# 2906                            0.576       12.5
# 2922                            0.507       10.3
#
# [194 rows x 8 columns]

# %%
null_value_index
# Out:
# Index([  32,   48,   64,   80,   96,  112,  128,  144,  160,  176,
#        ...
#        2778, 2794, 2810, 2826, 2842, 2858, 2874, 2890, 2906, 2922],
#       dtype='int64', length=194)

# %%
df_null.iloc[null_value_index]
# Out:
#                                  Country  Alcohol  Hepatitis B  \
# 32                               Algeria      NaN         95.0
# 48                                Angola      NaN         64.0
# 64                   Antigua and Barbuda      NaN         99.0
# 80                             Argentina      NaN         94.0
# 96                               Armenia      NaN         94.0
# ...                                  ...      ...          ...
# 2858  Venezuela (Bolivarian Republic of)      NaN         87.0
# 2874                            Viet Nam      NaN         97.0
# 2890                               Yemen      NaN         69.0
# 2906                              Zambia      NaN          9.0
# 2922                            Zimbabwe      NaN         87.0
#
#       Total expenditure           GDP  Population  \
# 32                  NaN   4132.762920  39871528.0
# 48                  NaN   3695.793748   2785935.0
# 64                  NaN  13566.954100         NaN
# 80                  NaN  13467.123600  43417765.0
# 96                  NaN    369.654776    291695.0
# ...                 ...           ...         ...
# 2858                NaN           NaN         NaN
# 2874                NaN           NaN         NaN
# 2890                NaN           NaN         NaN
# 2906                NaN   1313.889646    161587.0
# 2922                NaN    118.693830  15777451.0
#
#       Income composition of resources  Schooling
# 32                              0.743       14.4
# 48                              0.531       11.4
# 64                              0.784       13.9
# 80                              0.826       17.3
# 96                              0.741       12.7
# ...                               ...        ...
# 2858                            0.769       14.3
# 2874                            0.678       12.6
# 2890                            0.499        9.0
# 2906                            0.576       12.5
# 2922                            0.507       10.3
#
# [194 rows x 8 columns]

# %%
df_null.fillna(method="bfill").iloc[null_value_index]
# Out:
#                                  Country  Alcohol  Hepatitis B  \
# 32                               Algeria     0.01         95.0
# 48                                Angola     8.33         64.0
# 64                   Antigua and Barbuda     8.56         99.0
# 80                             Argentina     7.93         94.0
# 96                               Armenia     3.91         94.0
# ...                                  ...      ...          ...
# 2858  Venezuela (Bolivarian Republic of)     6.47         87.0
# 2874                            Viet Nam     4.09         97.0
# 2890                               Yemen     0.01         69.0
# 2906                              Zambia     0.01          9.0
# 2922                            Zimbabwe     6.50         87.0
#
#       Total expenditure           GDP  Population  \
# 32                 7.21   4132.762920  39871528.0
# 48                 3.31   3695.793748   2785935.0
# 64                 5.54  13566.954100  43417765.0
# 80                 4.79  13467.123600  43417765.0
# 96                 4.48    369.654776    291695.0
# ...                 ...           ...         ...
# 2858               5.26   1313.889646    161587.0
# 2874               7.70   1313.889646    161587.0
# 2890               5.64   1313.889646    161587.0
# 2906               4.99   1313.889646    161587.0
# 2922               6.44    118.693830  15777451.0
#
#       Income composition of resources  Schooling
# 32                              0.743       14.4
# 48                              0.531       11.4
# 64                              0.784       13.9
# 80                              0.826       17.3
# 96                              0.741       12.7
# ...                               ...        ...
# 2858                            0.769       14.3
# 2874                            0.678       12.6
# 2890                            0.499        9.0
# 2906                            0.576       12.5
# 2922                            0.507       10.3
#
# [194 rows x 8 columns]

# %%
alcohol_filter_null = df_null["Alcohol"].isnull()
hepatitis_filter_null = df_null["Hepatitis B"].isnull()

# %%
df_null[alcohol_filter_null | hepatitis_filter_null]
# Out:
#        Country  Alcohol  Hepatitis B  Total expenditure          GDP  \
# 32     Algeria      NaN         95.0                NaN  4132.762920
# 44     Algeria     0.34          NaN               3.60   294.335560
# 45     Algeria     0.36          NaN               3.73  1774.336730
# 46     Algeria     0.23          NaN               3.84  1732.857979
# 47     Algeria     0.25          NaN               3.49  1757.177970
# ...        ...      ...          ...                ...          ...
# 2918    Zambia     2.33          NaN               8.18   429.158343
# 2919    Zambia     2.44          NaN               6.93   377.135244
# 2920    Zambia     2.61          NaN               6.56   378.273624
# 2921    Zambia     2.62          NaN               7.16   341.955625
# 2922  Zimbabwe      NaN         87.0                NaN   118.693830
#
#       Population  Income composition of resources  Schooling
# 32    39871528.0                            0.743       14.4
# 44     3243514.0                            0.663       11.5
# 45     3199546.0                            0.653       11.1
# 46    31592153.0                            0.644       10.9
# 47     3118366.0                            0.636       10.7
# ...          ...                              ...        ...
# 2918  11421984.0                            0.443       10.2
# 2919    111249.0                            0.433       10.0
# 2920   1824125.0                            0.424        9.8
# 2921   1531221.0                            0.418        9.6
# 2922  15777451.0                            0.507       10.3
#
# [724 rows x 8 columns]

# %%
df_null["Alcohol"].fillna(method="bfill", inplace=True)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_10964\2110194112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_null["Alcohol"].fillna(method="bfill", inplace=True)

# %%
df_null.loc[null_value_index]
# Out:
#                                  Country  Alcohol  Hepatitis B  \
# 32                               Algeria     0.01         95.0
# 48                                Angola     8.33         64.0
# 64                   Antigua and Barbuda     8.56         99.0
# 80                             Argentina     7.93         94.0
# 96                               Armenia     3.91         94.0
# ...                                  ...      ...          ...
# 2858  Venezuela (Bolivarian Republic of)     6.47         87.0
# 2874                            Viet Nam     4.09         97.0
# 2890                               Yemen     0.01         69.0
# 2906                              Zambia     0.01          9.0
# 2922                            Zimbabwe     6.50         87.0
#
#       Total expenditure           GDP  Population  \
# 32                  NaN   4132.762920  39871528.0
# 48                  NaN   3695.793748   2785935.0
# 64                  NaN  13566.954100         NaN
# 80                  NaN  13467.123600  43417765.0
# 96                  NaN    369.654776    291695.0
# ...                 ...           ...         ...
# 2858                NaN           NaN         NaN
# 2874                NaN           NaN         NaN
# 2890                NaN           NaN         NaN
# 2906                NaN   1313.889646    161587.0
# 2922                NaN    118.693830  15777451.0
#
#       Income composition of resources  Schooling
# 32                              0.743       14.4
# 48                              0.531       11.4
# 64                              0.784       13.9
# 80                              0.826       17.3
# 96                              0.741       12.7
# ...                               ...        ...
# 2858                            0.769       14.3
# 2874                            0.678       12.6
# 2890                            0.499        9.0
# 2906                            0.576       12.5
# 2922                            0.507       10.3
#
# [194 rows x 8 columns]
